# %%
import sys
sys.path.append("../")

import gin
# %matplotlib inline
import matplotlib.pyplot as plt
from aae.Renderer import Renderer
from aae.Visualizations import plot_img, plot_batch

gin.parse_config_file('../config/camera.gin')

r = Renderer()

aug_imgs, img = r.produce_batch_images(batch_size=1)
plot_img(img)
# Out:
# /home/ham/.pyenv/versions/miniconda3-3.9.1/envs/aae/lib/python3.10/site-packages/imgaug/imgaug.py:184: DeprecationWarning: Function `ContrastNormalization()` is deprecated. Use `imgaug.contrast.LinearContrast` instead.
#   warn_deprecated(msg, stacklevel=3)

# %%
aug_imgs, imgs = r.produce_batch_images()
plot_batch(imgs)

# %%
plot_batch(aug_imgs)
